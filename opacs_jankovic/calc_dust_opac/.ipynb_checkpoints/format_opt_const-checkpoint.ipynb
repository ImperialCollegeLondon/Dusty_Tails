# %%
import numpy as np
from mpmath import findroot
import matplotlib.pyplot as plt

# %%
# inverts the order of elements in these arrays
def inv(w, n, k):
    wc = np.array(w)
    nc = np.array(n)
    kc = np.array(k)
    for i in range(len(w)):
        w[i] = wc[len(w)-1-i]
        n[i] = nc[len(w)-1-i]
        k[i] = kc[len(w)-1-i]
    return w, n, k

# %% [markdown]
# ## Bruggeman rule

# %%
# implements mixing of materials using Bruggeman rule
def mix(data, stp=complex(0.5,0.5), abund=1, adapt_stp=True):
    eps_all = np.array([ [complex(n, k)**2 for n, k in zip(dt[:,1], dt[:,2])] for dt in data ])
    
    if abund == 1:
        abund = [1/len(eps_all[:,0]) for i in range(len(eps_all[:,0]))]
    
    n = []
    k = []
    for i in range(len(eps_all[0])):
        eps = eps_all[:,i]
        
        def eqn(x):
            s = complex(0)
            for e, a in zip(eps, abund):
                s += a * (e - x) / (e + 2 * x)
            return s

        eps_mean = complex(findroot(eqn, stp))
        if adapt_stp:
            stp = eps_mean
        
        a = eps_mean.real
        b = eps_mean.imag
        kcsq = 0.5*(-a+np.sqrt(a**2+b**2))
        kc = np.sqrt(kcsq)
        nc = b/(2*kc)
        n.append(nc)
        k.append(kc)

    return n, k

# %% [markdown]
# ## Plotter

# %%
# produces plots of optical constants provided on input
def plot(w, n, k):
    plt.plot(w, n)
    plt.ylim(0, 5.2)
    plt.ylabel(r'$n(\lambda)$')
    plt.xscale('log')
    plt.xlim(0.01, 100)
    plt.xlabel(r'wavelength $\lambda$ [$\mu$m]')
    plt.show()
    
    plt.plot(w, k)
    plt.yscale('log')
    plt.ylim(2e-6, 5e1)
    plt.ylabel(r'$k(\lambda)$')
    plt.xscale('log')
    plt.xlim(0.01, 100)
    plt.xlabel(r'wavelength $\lambda$ [$\mu$m]')
    plt.show()

# %% [markdown]
# ## iron_O88

# %% [markdown]
# Data digitized from the publication.

# %%
direct = 'iron_O88'

data = np.loadtxt(direct+'/O88_Table_2.dat')
w = [1/k*1e4 for k in data[:,0]]
n = data[:,1]
k = data[:,2]

print(n)
w, n, k = inv(w, n, k)



plot(w, n, k)
    
output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# [238.5194    183.41621   147.11263   120.39992    95.35771    75.191427
#   61.295883   51.169978   43.260218   36.866495   31.895957   24.861494
#   20.259827   17.093309   14.820484   13.13127    10.825531    9.3532527
#    8.3467645   7.6216326   7.0686579   6.1662033   5.6202947   5.250716
#    4.9822242   4.7769777   4.613996    4.4807297   4.3691978   4.2740535
#    4.1915574   4.1189946   4.0543264   3.9959802   3.9427114   3.8935181
#    3.8475818   3.7628981   3.6845745   3.6099615   3.5376077   3.467115
#    3.3989889   3.3344296   3.2750676   3.2227697   3.1837613   3.0937414
#    3.0342872   2.973633    2.9443374   2.8735043]
# 52

# %%
w
# Out:
# [0.6666666666666667,
#  0.7142857142857143,
#  0.7692307692307693,
#  0.8333333333333333,
#  0.9090909090909091,
#  1.0,
#  1.0526315789473686,
#  1.1111111111111112,
#  1.1764705882352942,
#  1.25,
#  1.3333333333333335,
#  1.4285714285714286,
#  1.5384615384615385,
#  1.6666666666666665,
#  1.8181818181818181,
#  2.0,
#  2.105263157894737,
#  2.2222222222222223,
#  2.3529411764705883,
#  2.5,
#  2.666666666666667,
#  2.857142857142857,
#  3.076923076923077,
#  3.333333333333333,
#  3.6363636363636362,
#  4.0,
#  4.444444444444445,
#  5.0,
#  5.714285714285714,
#  6.666666666666666,
#  8.0,
#  10.0,
#  11.11111111111111,
#  12.5,
#  14.285714285714286,
#  16.666666666666668,
#  20.0,
#  22.22222222222222,
#  25.0,
#  28.571428571428573,
#  33.333333333333336,
#  40.0,
#  44.44444444444444,
#  50.0,
#  57.142857142857146,
#  66.66666666666667,
#  80.0,
#  100.0,
#  125.0,
#  153.84615384615387,
#  200.0,
#  285.7142857142857]

# %% [markdown]
# ## fayalite_F01

# %% [markdown]
# Data downloaded from JENA database.

# %%
direct = 'fayalite_F01'

files = ['fay_nk_x.txt', 'fay_nk_y.txt', 'fay_nk_z.txt']
data = []
for file in files:
    print(np.loadtxt(direct+'/'+file, skiprows=7))
    data.append(np.loadtxt(direct+'/'+file, skiprows=7))
data = np.array(data)

w = [1/k*1e4 for k in data[0,:,0]]
n, k = mix(data)

w, n, k = inv(w, n, k)

data = np.loadtxt(direct+'/fay_vis.txt', skiprows=6)
ws = [1/k*1e4 for k in data[:,0]]
ns = data[:,1]
ks = data[:,2]
ws, ns, ks = inv(ws, ns, ks)

w = np.concatenate((ws, w[4001:]))
n = np.concatenate((ns, n[4001:]))
k = np.concatenate((ks, k[4001:]))

print(w)

plot(w, n, k)
    
output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# [[1.0000000e+00 3.0106835e+00 1.0180000e-04]
#  [2.0000000e+00 3.0107145e+00 2.0370000e-04]
#  [3.0000000e+00 3.0107648e+00 3.0560000e-04]
#  ...
#  [4.9980000e+03 1.8618094e+00 2.5900000e-05]
#  [4.9990000e+03 1.8618141e+00 2.5900000e-05]
#  [5.0000000e+03 1.8618189e+00 2.5800000e-05]]
# [[1.0000000e+00 2.9038665e+00 1.1170000e-04]
#  [2.0000000e+00 2.9039104e+00 2.2340000e-04]
#  [3.0000000e+00 2.9039810e+00 3.3520000e-04]
#  ...
#  [4.9980000e+03 1.7660365e+00 1.8700000e-05]
#  [4.9990000e+03 1.7660401e+00 1.8700000e-05]
#  [5.0000000e+03 1.7660437e+00 1.8700000e-05]]
# [[1.0000000e+00 2.9101224e+00 9.5800000e-05]
#  [2.0000000e+00 2.9101560e+00 1.9150000e-04]
#  [3.0000000e+00 2.9102099e+00 2.8740000e-04]
#  ...
#  [4.9980000e+03 1.7877258e+00 2.7400000e-05]
#  [4.9990000e+03 1.7877301e+00 2.7400000e-05]
#  [5.0000000e+03 1.7877344e+00 2.7300000e-05]]
# [4.00000000e-01 4.00192188e-01 4.00384561e-01 ... 3.33333333e+03
#  5.00000000e+03 1.00000000e+04]
# 2998

# %% [markdown]
# ## enstatite_J98_J94_D95

# %% [markdown]
# Data downloaded from JENA database.

# %%
direct = 'enstatite_J98_J94_D95'

files = ['ens_p.txt', 'ens_s1.txt', 'ens_s2.txt']
data = []
for file in files:
    data.append(np.loadtxt(direct+'/'+file))
data = np.array(data)
print(data)
w = data[0,:,0]
n, k = mix(data)

data = np.loadtxt(direct+'/pyrmg100.txt')
ws = data[:,0]
ns = data[:,1]
ks = data[:,2]

w = np.concatenate((ws[6:46], w[23:]))
n = np.concatenate((ns[6:46], n[23:]))
k = np.concatenate((ks[6:46], k[23:]))

plot(w, n, k)

output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# [[[2.00000e+00 1.49235e+00 1.31700e-02]
#   [2.50000e+00 1.47786e+00 1.66200e-02]
#   [3.00000e+00 1.46848e+00 1.93400e-02]
#   ...
#   [9.61268e+01 2.55232e+00 1.15420e-01]
#   [9.75000e+01 2.55175e+00 1.44060e-01]
#   [9.89130e+01 2.58553e+00 1.26990e-01]]
#
#  [[2.00000e+00 1.57847e+00 1.35850e-02]
#   [2.50000e+00 1.56963e+00 1.53300e-02]
#   [3.00000e+00 1.55525e+00 1.66100e-02]
#   ...
#   [9.61268e+01 2.82156e+00 2.78700e-02]
#   [9.75000e+01 2.76654e+00 1.89700e-01]
#   [9.89130e+01 2.95695e+00 1.47030e-01]]
#
#  [[2.00000e+00 1.55733e+00 1.14850e-02]
#   [2.50000e+00 1.54907e+00 1.45400e-02]
#   [3.00000e+00 1.54059e+00 1.85300e-02]
#   ...
#   [9.61268e+01 2.67936e+00 5.47500e-02]
#   [9.75000e+01 2.69201e+00 3.48700e-02]
#   [9.89130e+01 2.66821e+00 1.37100e-02]]]
# 825

# %% [markdown]
# ## olivine_F01 (Mg2SiO4 - Forsterite) Mg end member of Olivine

# %% [markdown]
# Data downloaded from JENA database.

# %%
direct = 'olivine_F01'

files = ['oliv_nk_x.txt', 'oliv_nk_y.txt', 'oliv_nk_z.txt']
data = []
data.append(np.loadtxt(direct+'/'+files[0], skiprows=7))
data.append(np.loadtxt(direct+'/'+files[1], skiprows=6))
data.append(np.loadtxt(direct+'/'+files[2], skiprows=5))
data = np.array(data)

w = [1/k*1e4 for k in data[0,:,0]]
n, k = mix(data)
w, n, k = inv(w, n, k)

data = np.loadtxt(direct+'/oliv_vis.txt', skiprows=5)
ws = [1/k*1e4 for k in data[:,0]]
ns = data[:,1]
ks = data[:,2]
ws, ns, ks = inv(ws, ns, ks)

w = np.concatenate((ws, w))
n = np.concatenate((ns, n))
k = np.concatenate((ks, k))

plot(w, n, k)
    
output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# 5080

# %% [markdown]
# ## quartz_Z13

# %% [markdown]
# Data downloaded from JENA database.

# %%
direct = 'quartz_Z13'

temp = '928'
files = ['quartz_Epara_'+temp+'Knew.txt', 'quartz_Eperp_'+temp+'Knew.txt']
data = []
for file in files:
    data.append(np.loadtxt(direct+'/'+file))
data = np.array(data)

w = data[0,:,0]
#n, k = mix(data)
n, k = mix(data, abund=[0.33,0.67])
w, n, k = inv(w, n, k)

plot(w, n, k)

output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# 1600

# %% [markdown]
# ## corundum_K95

# %% [markdown]
# Data digitized from the publication.

# %%
direct = 'corundum_K95'

data = np.loadtxt(direct+'/opt_const.dat')
w = data[:,0]
n = data[:,1]
k = data[:,2]

plot(w, n, k)
print(len(w))
# Out:
# 267

# %% [markdown]
# ## silicon_carbide_L93

# %% [markdown]
# Data from Draine's website.

# %%
direct = 'silicon_carbide_L93'

data = np.loadtxt(direct+'/eps_SiC', skiprows=6)
w = data[:,0]
n = [nc+1 for nc in data[:,3]]
k = data[:,4]

w, n, k = inv(w, n, k)

plot(w, n, k)

output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# 1201

# %% [markdown]
# ## graphite_D84

# %% [markdown]
# Data from Draine's website.

# %%
direct = 'graphite_D84'

files = ['callindex.out_CpaD03_0.10', 'callindex.out_CpeD03_0.10']
data1 = np.loadtxt(direct+'/'+files[0], skiprows=5, usecols=(0,3,4))
data2 = np.loadtxt(direct+'/'+files[1], skiprows=5, usecols=(0,3,4))

for i in range(len(data1[:,0])):
    data1[i,1] = data1[i,1]+1
for i in range(len(data2[:,0])):
    data2[i,1] = data2[i,1]+1

data2_new = np.array(data1)
j = 0
for i in range(len(data1[:,0])):
    while j < len(data2[:,0])-2 and data1[i,0] < data2[j,0]:
        j += 1
    
    data2_new[i,0] = data1[i,0]
    data2_new[i,1] = data2[j,1] + (data1[i,0]-data2[j,0])*(data2[j+1,1]-data2[j,1])/(data2[j+1,0]-data2[j,0])
    data2_new[i,2] = data2[j,2] + (data1[i,0]-data2[j,0])*(data2[j+1,2]-data2[j,2])/(data2[j+1,0]-data2[j,0])

#w1 = data2[:,0]
#n1 = data2[:,1]
#k1 = data2[:,2]
#w2 = data2_new[:,0]
#n2 = data2_new[:,1]
#k2 = data2_new[:,2]
#plot(w1, n1, k1)
#plot(w2, n2, k2)

data2 = np.array(data2_new)
data = np.array([data1, data2])

w = data[0,:,0]
n, k = mix(data, abund=[0.33,0.67], adapt_stp=False)
w, n, k = inv(w, n, k) 

plot(w, n, k)

output = np.transpose(np.array([w[7:],n[7:],k[7:]])) # exclude infs and zeros
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# C:\Users\mj516\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:26: RuntimeWarning: divide by zero encountered in double_scalars
# 386

# %% [markdown]
# ## graphite_D84_test

# %%
direct = 'graphite_D84_test'

files = ['callindex.out_CpaD03_0.10', 'callindex.out_CpeD03_0.10']
data1 = np.loadtxt(direct+'/'+files[0], skiprows=5, usecols=(0,3,4))
data2 = np.loadtxt(direct+'/'+files[1], skiprows=5, usecols=(0,3,4))

for i in range(len(data1[:,0])):
    data1[i,1] = data1[i,1]+1
for i in range(len(data2[:,0])):
    data2[i,1] = data2[i,1]+1

data2_new = np.array(data1)
j = 0
for i in range(len(data1[:,0])):
    while j < len(data2[:,0])-2 and data1[i,0] < data2[j,0]:
        j += 1
    
    data2_new[i,0] = data1[i,0]
    data2_new[i,1] = data2[j,1] + (data1[i,0]-data2[j,0])*(data2[j+1,1]-data2[j,1])/(data2[j+1,0]-data2[j,0])
    data2_new[i,2] = data2[j,2] + (data1[i,0]-data2[j,0])*(data2[j+1,2]-data2[j,2])/(data2[j+1,0]-data2[j,0])

#w1 = data2[:,0]
#n1 = data2[:,1]
#k1 = data2[:,2]
#w2 = data2_new[:,0]
#n2 = data2_new[:,1]
#k2 = data2_new[:,2]
#plot(w1, n1, k1)
#plot(w2, n2, k2)

data2 = np.array(data2_new)
data = np.array([data1, data2])

w = data[0,:,0]
n, k = mix(data, abund=[0.33,0.67], adapt_stp=False)
#w, n, k = inv(w, n, k) 

plot(w, n, k)

output = np.transpose(np.array([w[7:],n[7:],k[7:]])) # exclude infs and zeros
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# C:\Users\mj516\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:26: RuntimeWarning: divide by zero encountered in double_scalars
# 386

# %% [markdown]
# # MgFeSiO4

# %%
direct = 'MgFeSiO4_J94_D95'

file = 'jena_data.txt'
data = np.loadtxt(direct+'/'+file, skiprows=0)
w = data[:,0]
n = data[:,1]
k = data[:,2]

# %%
plot(w,n,k)
output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)

# %% [markdown]
# # Mg08Fe12SiO4

# %%
direct = 'Mg08Fe12SiO4_D95'

file = 'Mg08Fe12SiO4_amorph_glass.dat'
data = np.loadtxt(direct+'/'+file, skiprows=3)
w = data[:,0]
n = data[:,1]
k = data[:,2]

# %%
plot(w,n,k)
output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)

# %% [markdown]
# # Mg05Fe05SiO3 - pyroxene

# %%
direct = 'Mg05Fe05SiO3_J94_D95'

file = 'pyrmg50.txt'
data = np.loadtxt(direct+'/'+file, skiprows=3)
w = data[:,0]
n = data[:,1]
k = data[:,2]

# %%
plot(w,n,k)
output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)

# %% [markdown]
# # Mg04Fe06SiO3 - pyroxene

# %%
direct = 'Mg04Fe06SiO3_J94_D95'

file = 'pyrmg40.txt'
data = np.loadtxt(direct+'/'+file, skiprows=3)
w = data[:,0]
n = data[:,1]
k = data[:,2]

# %%
plot(w,n,k)
output = np.transpose(np.array([w,n,k]))
np.savetxt(direct+'/opt_const.dat', output)

# %% [markdown]
# # Sri Lanka Olivine (Mg1.56Fe0.4Si0.91O4)

# %%
direct = 'OlivineSL_Z11'

files = ['olivineSL_y.txt', 'olivineSL_z.txt']
data = []
for file in files:
    data.append(np.loadtxt(direct+'/'+file))
data = np.array(data)

w = data[0,:,0]

n, k = mix(data)

plot(w, n, k)

output = np.transpose(np.array([w,n,k]))


print(type(output))
np.savetxt(direct+'/opt_const.dat', output)
print(len(w))
# Out:
# [[6.99793050e+00 1.45266096e+00 2.86517541e-03]
#  [6.99321175e+00 1.45301313e+00 2.83668040e-03]
#  [6.98849936e+00 1.45336308e+00 2.81008112e-03]
#  ...
#  [3.80500000e-01 1.63291600e+00 9.03229261e-05]
#  [3.80250000e-01 1.63291680e+00 9.21811064e-05]
#  [3.80000000e-01 1.63291757e+00 9.26182546e-05]]
# 10339

# %%
output = sorted(output, key= lambda x: x[0])

# %%
np.savetxt(direct+'/opt_const.dat', output)

# %%
output_short = output[::10]

# %%
np.size(output_short)
# Out:
# 1551

# %%
np.savetxt(direct+'/opt_const.dat', output_short)
